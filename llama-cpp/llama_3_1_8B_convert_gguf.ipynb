# %%
from google.colab import userdata
from huggingface_hub import login

# %%
login(token=userdata.get('niru_hf_read'))

# %%
from huggingface_hub import snapshot_download

model_id = "meta-llama/Llama-3.1-8B"

snapshot_download(repo_id=model_id, local_dir="llama3.1-8B",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:832: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
# ...

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# !pip install -r llama.cpp/requirements.txt

# %%
# !python /content/llama.cpp/convert_hf_to_gguf.py llama3.1-8B --outfile llama3.1_8b.gguf --outtype q8_0
# Out:
# INFO:hf-to-gguf:Loading model: llama3.1-8B
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {64}
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00004.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.bfloat16 --> Q8_0, shape = {4096, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.bfloat16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.bfloat16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.bfloat16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.bfloat16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {4096}
# ...

# %% [markdown]
# load llama3.1-8B_gguf model

# %%
# !pip install -q llama-cpp-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 12.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from llama_cpp import Llama

llm = Llama(model_path="/content/llama3.1_8b.gguf")

# %%
prompt = "explain the large language models"

output = llm(prompt, max_tokens=300)
print(output['choices'][0]['text'])
# Out:
# Llama.generate: 5 prefix-match hit, remaining 1 prompt tokens to eval
# llama_perf_context_print:        load time =    3587.64 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =  304298.90 ms /   300 runs   ( 1014.33 ms per token,     0.99 tokens per second)
# llama_perf_context_print:       total time =  304747.43 ms /   301 tokens
# explain the large language models (LLMs) such as OpenAI’s GPT-3 and Google’s PaLM;
# discuss the capabilities and limitations of LLMs;
# describe the current and future potential of LLMs in the enterprise; and
# explore how to use LLMs in the enterprise.
# ...

# %%
prompt = "write the LSTM code in python"

output = llm(prompt, max_tokens=800)
print(output['choices'][0]['text'])
# Out:
# Llama.generate: 1 prefix-match hit, remaining 6 prompt tokens to eval
# llama_perf_context_print:        load time =    3587.64 ms
# llama_perf_context_print: prompt eval time =    1995.79 ms /     6 tokens (  332.63 ms per token,     3.01 tokens per second)
# llama_perf_context_print:        eval time =  296210.73 ms /   299 runs   (  990.67 ms per token,     1.01 tokens per second)
# llama_perf_context_print:       total time =  298647.35 ms /   305 tokens
# write the LSTM code in python
# Post by ying » Tue Nov 03, 2020 9:54 am
# I am trying to use the LSTM to classify the speech with python. I read the LSTM tutorial in the website, but the code is in MATLAB.
# I found the LSTM code in the website:
# But I can not run it as I do not know the code.
# I would appreciate it if you can write the code in python.
# Re: write the LSTM code in python
# Post by ying » Tue Nov 03, 2020 6:04 pm
# Thanks for your response, I already read the tutorial, but there is no code in the tutorial.
# ...

# %%
from google.colab import userdata
from huggingface_hub import login, HfApi, create_repo

# %%
login(token=userdata.get('niru_hf_write'))

# %%
api = HfApi()

model_id = "nirusanan/llama-gguf"

api.create_repo(model_id, exist_ok=True, repo_type="model", private=True)

api.upload_file(
    path_or_fileobj="/content/llama3.1_8b.gguf",
    path_in_repo="llama3.1-q8_0.gguf",
    repo_id=model_id,
)
# Out:
# llama3.1_8b.gguf:   0%|          | 0.00/8.54G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nirusanan/llama-gguf/commit/2fc86f5f631f1bd8664b878a9f6f72cebdeb3d35', commit_message='Upload llama3.1-q8_0.gguf with huggingface_hub', commit_description='', oid='2fc86f5f631f1bd8664b878a9f6f72cebdeb3d35', pr_url=None, repo_url=RepoUrl('https://huggingface.co/nirusanan/llama-gguf', endpoint='https://huggingface.co', repo_type='model', repo_id='nirusanan/llama-gguf'), pr_revision=None, pr_num=None)
